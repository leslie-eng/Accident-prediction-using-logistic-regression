# %% [markdown]
# ## Problem Statement
# According to the news report, the total number of accidents that we have had in Kenya as of 2025 was 4458. https://www.citizen.digital/article/ntsa-reports-spike-in-road-fatalities-as-2025-death-toll-hits-4458-n374206. The rise of road accidents on Kenya Roads often happen due to a chain of small warnings ignored such as vehicle condition, weather, driver behaviour, speed, traffic density, condition of roads, positioning of road signs and time of day, driver experience, drug & alcohol usage, smartphone usage, location of accidents.

# %% [markdown]
# ### Core Idea
# The model is able to label the risks based on three outcomes: low risk, medium risk and high risk.

# %% [markdown]
# ## Preparation of Data

# %%
# import the dataframe
import pandas as pd

# visualizations
import seaborn as sns
import matplotlib.pyplot as plt

# splitting of data
from sklearn.model_selection import train_test_split, GridSearchCV


# training the model with data
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.impute import SimpleImputer
from imblearn.over_sampling import RandomOverSampler

# evaluation of model
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, confusion_matrix

# save the model after training and tuning
import pickle

# %% [markdown]
# ### Create a wrangle function to import the excel file and convert it into a dataframe

# %%
def wrangle(filepath):
    df = pd.read_excel(filepath)
    return df

# %%
df = wrangle("Transport Safety And Driver Behavior Survey - Extended (1014 rows).xlsx")
df.head()
# Out:
#       Timestamp  \
# 0  46056.669304
# 1  46056.689522
# 2  46056.704804
# 3  46056.929537
# 4  46058.680718
#
#   Do you consent to participate in this anonymized research study?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   This survey does not collect names or identifying details. Do you agree to proceed?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Age group Gender Years of driving experience Type of driving license held  \
# 0     25-34   Male            Less than 1 year                      Private
# 1     25-34   Male                   3-5 years                   Commercial
# 2     25-34   Male                   3-5 years                      Private
# 3     25-34   Male            Less than 1 year                          NaN
# 4     18-24   Male                   1-3 years                      Private
#
#   Average driving frequency Primary vehicle type         Vehicle age  ...  \
# 0              Occasionally                  Car  More than 10 years  ...
# 1                     Daily           Motorcycle          5-10 years  ...
# 2                    Rarely                  Car  More than 10 years  ...
# 3                    Rarely                  Car   Less than 5 years  ...
# 4              Occasionally                  Car          5-10 years  ...
#
#   If yes, how many accidents? Primary cause of the most recent accident  \
# 0                         NaN                                       NaN
# 1                         NaN                                     Other
# 2                           1                                     Other
# 3                         NaN                                       NaN
# 4                           1                            Road condition
#
#   How would you rate your overall driving risk?  \
# 0                                           Low
# 1                                      Very low
# 2                                      Moderate
# 3                                           Low
# 4                                      Moderate
#
#   Do you believe road accidents are mostly preventable?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#    Type of driving training/class completed Column 34  \
# 0           Driving school – basic training       NaN
# 1  Professional/commercial driving training       NaN
# 2           Driving school – basic training       NaN
# 3  Formal training (self-taught / informal)       NaN
# 4           Driving school – basic training       NaN
#
#   How would you rate the visibility and clarity of road signs on your usual driving routes?  \
# 0                                                NaN
# 1                                           Adequate
# 2                                               Poor
# 3           Very poor (signs are missing or unclear)
# 4                                               Poor
#
#   Which County do you reside in? Column 36 Column 33
# 0                            NaN       NaN       NaN
# 1                            NaN       NaN       NaN
# 2                            NaN       NaN       NaN
# 3                         Nakuru       NaN       NaN
# 4                        Nairobi       NaN       NaN
#
# [5 rows x 39 columns]

# %%
df.shape
# Out:
# (1014, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 39 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   Timestamp                                                                                  1014 non-null   float64
#  1   Do you consent to participate in this anonymized research study?                           1014 non-null   object
#  2   This survey does not collect names or identifying details. Do you agree to proceed?        1014 non-null   object
#  3   Age group                                                                                  1014 non-null   object
#  4   Gender                                                                                     1014 non-null   object
#  5   Years of driving experience                                                                1014 non-null   object
#  6   Type of driving license held                                                               950 non-null    object
#  7   Average driving frequency                                                                  1014 non-null   object
#  8   Primary vehicle type                                                                       1014 non-null   object
#  9   Vehicle age                                                                                1014 non-null   object
#  10  When was the vehicle last serviced                                                         1014 non-null   object
#  11  Overall vehicle condition :                                                                1014 non-null   object
#  12  How often do you exceed the speed limit?                                                   1014 non-null   object
#  13  How often do you use a mobile phone while driving?                                         1014 non-null   object
#  14  How often do you make sudden or harsh braking maneuvers?                                   1014 non-null   object
#  15  How often do you feel distracted while driving?                                            1014 non-null   object
#  16  Seatbelt or helmet usage                                                                   1014 non-null   object
#  17  Typical hours of sleep before driving                                                      1014 non-null   object
#  18  Have you driven while extremely tired in the past month?                                   930 non-null    object
#  19  In the last 6 hours before driving, have you consumed alcohol?                             1014 non-null   object
#  20  Are you taking medication that may affect alertness?                                       1014 non-null   object
#  21  Primary driving environment                                                                1014 non-null   object
#  22  Typical road condition on your route                                                       1014 non-null   object
#  23  Road lighting quality                                                                      876 non-null    object
#  24  Most frequent weather condition while driving                                              948 non-null    object
#  25  Most common time of driving                                                                1014 non-null   object
#  26  Typical traffic level on your route                                                        1014 non-null   object
#  27  Do you often drive during rush hours?                                                      931 non-null    object
#  28  Have you been involved in a road accident in the past 5 years?                             1014 non-null   object
#  29  If yes, how many accidents?                                                                292 non-null    object
#  30  Primary cause of the most recent accident                                                  296 non-null    object
#  31  How would you rate your overall driving risk?                                              1014 non-null   object
#  32  Do you believe road accidents are mostly preventable?                                      1014 non-null   object
#  33  Type of driving training/class completed                                                   1014 non-null   object
#  34  Column 34                                                                                  0 non-null      float64
#  35  How would you rate the visibility and clarity of road signs on your usual driving routes?  945 non-null    object
#  36  Which County do you reside in?                                                             1011 non-null   object
#  37  Column 36                                                                                  0 non-null      float64
#  38  Column 33                                                                                  0 non-null      float64
# dtypes: float64(4), object(35)
# memory usage: 309.1+ KB
